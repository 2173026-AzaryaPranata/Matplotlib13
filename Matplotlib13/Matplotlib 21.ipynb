# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

print(matplotlib.__version__)
print(pd.__version__)
# Out:
# 3.5.2
# 1.4.4

# %%
data = {
    'Tahun':[
        '1958','1963','1968','1973','1978','1983','1988','1993','1998',
        '2003','2008','2013','2018'
    ],
    'Populasi':[
        5165200,53624900,55213500,56223000,56178000,56315000,56916000,
        57713000,58474000,59636000,61823000,64105000,66436000
    ]
}

df= pd.DataFrame(data)
df
# Out:
#    Tahun  Populasi
# 0   1958   5165200
# 1   1963  53624900
# 2   1968  55213500
# 3   1973  56223000
# 4   1978  56178000
# 5   1983  56315000
# 6   1988  56916000
# 7   1993  57713000
# 8   1998  58474000
# 9   2003  59636000
# 10  2008  61823000
# 11  2013  64105000
# 12  2018  66436000

# %%
df.plot(x='Tahun', y='Populasi', kind='line')
plt.title ('Data Populasi Penduduk')
plt.ylabel('Populasi')
plt.xlabel('Tahun')
plt.show()

# %%
data = {
        'Negara':['United States', 'Singapore', 'Germany', 'United Kingdom','Japan'],
        'GDP':[62606, 100345, 52559, 45705, 44227]
}


df= pd.DataFrame(data, columns =['Negara', 'GDP'])
df
# Out:
#            Negara     GDP
# 0   United States   62606
# 1       Singapore  100345
# 2         Germany   52559
# 3  United Kingdom   45705
# 4           Japan   44227

# %%
df.plot(x='Negara', y='GDP', kind='bar')

plt.tittle('GDP Per Kapita')
plt.ylabel('GDP dalam USD')
plt.xlabel('Negara')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23168\1367264931.py in <module>
#       1 df.plot(x='Negara', y='GDP', kind='bar')
#       2
# ----> 3 plt.tittle('GDP Per Kapita')
#       4 plt.ylabel('GDP dalam USD')
#       5 plt.xlabel('Negara')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
df.plot(x='Negara', y='GDP', kind='barh')

plt.tittle('GDP Per Kapita')
plt.ylabel('GDP dalam USD')
plt.xlabel('Negara')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23168\2865199384.py in <module>
#       1 df.plot(x='Negara', y='GDP', kind='barh')
#       2
# ----> 3 plt.tittle('GDP Per Kapita')
#       4 plt.ylabel('GDP dalam USD')
#       5 plt.xlabel('Negara')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
df.plot(x='Negara', y='GDP', kind='barh', color='green', legend=False)

plt.tittle('GDP Per Kapita')
plt.ylabel('GDP dalam USD')
plt.xlabel('Negara')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23168\385340368.py in <module>
#       1 df.plot(x='Negara', y='GDP', kind='barh', color='green', legend=False)
#       2
# ----> 3 plt.tittle('GDP Per Kapita')
#       4 plt.ylabel('GDP dalam USD')
#       5 plt.xlabel('Negara')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
data = {
        'Negara':['United States', 'Singapore', 'Germany', 'United Kingdom','Japan'],
        'GDP':[52591, 67110, 46426, 38749, 36030],
        'Life_Expectany':[79.24, 82.84, 80.84, 81.40, 83.62]
}


df= pd.DataFrame(data, columns =['Negara', 'GDP', 'Life_Expectany'])
df
# Out:
#            Negara    GDP  Life_Expectany
# 0   United States  52591           79.24
# 1       Singapore  67110           82.84
# 2         Germany  46426           80.84
# 3  United Kingdom  38749           81.40
# 4           Japan  36030           83.62

# %%
df.plot(kind='scatter',x='GDP', y='Life_Expectancy', color='red')

plt.tittle('GDP dan Life Expectancy')
plt.ylabel('Life Expectany')
plt.xlabel('GDP dan USD')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Life_Expectancy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data = {
    'benua':[
        'South America','Ocenia', 'North America', 'Europe', 'Asia',
        'Antarctic', 'Africa'
    ],
    'populasi':
    [42253000, 38304000, 579024000, 738849000, 4581757408, 1106, 1216130000]
}

df= pd.DataFrame(data)
df
# Out:
#            benua    populasi
# 0  South America    42253000
# 1         Ocenia    38304000
# 2  North America   579024000
# 3         Europe   738849000
# 4           Asia  4581757408
# 5      Antarctic        1106
# 6         Africa  1216130000

# %%
df.plot(kind='pie', y='populasi', figsize=(6,6))

plt.tittle('Populasi di tiap Benua')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23168\1953790446.py in <module>
#       1 df.plot(kind='pie', y='populasi', figsize=(6,6))
#       2
# ----> 3 plt.tittle('Populasi di tiap Benua')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
df=df.set_index('benua')
df
# Out:
#                  populasi
# benua
# South America    42253000
# Ocenia           38304000
# North America   579024000
# Europe          738849000
# Asia           4581757408
# Antarctic            1106
# Africa         1216130000

# %%
df.plot(kind='pie', y='populasi', figsize=(6,6))

plt.tittle('Populasi di tiap Benua')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23168\1953790446.py in <module>
#       1 df.plot(kind='pie', y='populasi', figsize=(6,6))
#       2
# ----> 3 plt.tittle('Populasi di tiap Benua')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
data = {
    'benua':[
        'South America','Ocenia', 'North America', 'Europe', 'Asia',
        'Antarctic', 'Africa'
    ],
    'populasi':
    [42253000, 38304000, 579024000, 738849000, 4581757408, 1106, 1216130000]
}

df= pd.DataFrame(data)
df
# Out:
#            benua    populasi
# 0  South America    42253000
# 1         Ocenia    38304000
# 2  North America   579024000
# 3         Europe   738849000
# 4           Asia  4581757408
# 5      Antarctic        1106
# 6         Africa  1216130000

# %%
df['populasi'].plot(kind='box')

plt.tittle('Sebaran Populasi')
plt.ylabel('jumlah')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23168\1864936528.py in <module>
#       1 df['populasi'].plot(kind='box')
#       2
# ----> 3 plt.tittle('Sebaran Populasi')
#       4 plt.ylabel('jumlah')
#       5
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'
